# %% [markdown]
# You are given coins of different denominations and a total amount of money amount. Write a function to compute the fewest number of coins that you need to make up that amount. If that amount of money cannot be made up by any combination of the coins, return -1.
#
# You may assume that you have an infinite number of each kind of coin.
#
#
#
# Example 1:
#
# Input: coins = [1,2,5], amount = 11
# Output: 3
# Explanation: 11 = 5 + 5 + 1
# Example 2:
#
# Input: coins = [2], amount = 3
# Output: -1
# Example 3:
#
# Input: coins = [1], amount = 0
# Output: 0
# Example 4:
#
# Input: coins = [1], amount = 1
# Output: 1
# Example 5:
#
# Input: coins = [1], amount = 2
# Output: 2

# %%
from typing import List

# %%
def fewest_coins(coins: List, amount: int) -> int:
    '''
    n = len(coins)
    m = range(amount)
    O(m*2^N ) Brute force / recursive DFS:
    1. Base case: current >= amount
    2. At every iteration, we have n choice of actions 
    3. When we hit base case, if current == amount, return num of coins, else, return nothing
    4. Return max of these

    '''
    coins = sorted(coins)
    #Recursion method
    results = set()
    def recurse(current, num_coins):
        if current == amount:
            results.add(num_coins)
        elif current < amount:
            for coin in coins:
                result = recurse(current+coin, num_coins+1)
                    
    
    
    
    recurse(0, 0)
    print(results)
    print(min(results))

# %%
fewest_coins([2,3,5], 200)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-9eaf74230510> in <module>
# ----> 1 fewest_coins([2,3,5], 200)
#
# <ipython-input-42-c6801c331faf> in fewest_coins(coins, amount)
#      23
#      24
# ---> 25     recurse(0, 0)
#      26     print(results)
#      27     print(min(results))
#
# <ipython-input-42-c6801c331faf> in recurse(current, num_coins)
#      18         elif current < amount:
#      19             for coin in coins:
# ---> 20                 result = recurse(current+coin, num_coins+1)
#      21
#      22
#
# <ipython-input-42-c6801c331faf> in recurse(current, num_coins)
#      18         elif current < amount:
#      19             for coin in coins:
# ---> 20                 result = recurse(current+coin, num_coins+1)
#      21
#      22
#
# <ipython-input-42-c6801c331faf> in recurse(current, num_coins)
# ...

# %%
def fewest_coins_dp(coins: List, amount: int) -> int:
    '''
    n = len(coins)
    m = range(amount)

    O(m*n) Dynamic Programming:
    1. Initialise  dp array and solve it 
    '''
    # Dynamic method
    n = len(coins)
    coins = sorted(coins)
    dp = [[None for _ in range(amount)] for __ in range(n)]

    for i in range(amount):
        if (i+1)% coins[0] == 0:
            dp[0][i] = (i+1)/coins[0]
        else:
            dp[0][i] = None 
    
    for coin_index in range(1,n):
        for amt in range(1,amount+1):
            if amt%coins[coin_index] ==0:
                dp[coin_index][amt-1] = (amt)/coins[coin_index]
            else:
                above = dp[coin_index-1][amt-1]
                left = None
                if amt>coins[coin_index]:
                    left = dp[coin_index][amt-coins[coin_index]-1]
                if left and above:
                    dp[coin_index][amt-1] = min(left+1,above)
                elif left:
                    dp[coin_index][amt-1] = left + 1
                elif above:
                    dp[coin_index][amt-1] = above
                else:
                    dp[coin_index][amt-1] = None
    
    return(dp[-1][-1])

# %%
fewest_coins_dp([2,3,5],200)
# Out:
# 40.0

# %%
i = [10]
lst = [1,2,3,4]

# %%
# Out:
#   File "<ipython-input-33-5c46068c629a>", line 1
#     lst[i-=7]
#           ^
# SyntaxError: invalid syntax
